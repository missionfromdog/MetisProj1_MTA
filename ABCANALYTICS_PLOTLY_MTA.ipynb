# %%
import plotly.offline as py
import plotly.graph_objs as go
import pandas as pd

py.init_notebook_mode(connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('data/stations.csv')
crs = {'init': 'epsg = 2263'}
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-33cdc3ed756c> in <module>
# ----> 1 df = pd.read_csv('data/stations.csv')
#       2 crs = {'init': 'epsg = 2263'}
#       3 df.head()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
# ...

# %%
mapbox_access_token = 'pk.eyJ1IjoibWlzc2lvbmZyb21kb2ciLCJhIjoiY2pxcjZmNWlkMGp3bjQxcGV6ZGZldmcxdSJ9.Bi0MVaWrcPYFykUvk3Ptcw'

# %%
data = [
    go.Scattermapbox(
        lon= df["GTFS Longitude"].values,
        lat= df["GTFS Latitude"].values,
        mode='markers',
        marker=dict(
            size=16,
            color='blue',
            opacity=0.2
        ),
        text=['NYC'],
    )
]

# %%
layout = go.Layout(
    autosize=True, height=800,
    hovermode='closest',
    mapbox=dict(
        accesstoken=mapbox_access_token,
        bearing=0,
        center=dict(
            lat=40.7,
            lon=-73.93
        ),
        pitch=0,
        zoom=10
    ),
)

fig = dict(data=data, layout=layout)

py.iplot(fig, filename='NYC MTA Data')
# Out:
# <div id="a31ffcc3-2b2c-4619-a189-dcf8ebf6cdb4" style="height: 800px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a31ffcc3-2b2c-4619-a189-dcf8ebf6cdb4", [{"lat": [40.775036, 40.770258, 40.766779, 40.76182, 40.756803999999995, 40.752882, 40.76266, 40.764811, 40.764664, 40.759901, 40.754672, 40.749567, 40.745494, 40.741303, 40.735735999999996, 40.730328, 40.724329, 40.719527, 40.718383, 40.713282, 40.710668, 40.70722, 40.703087, 40.6941, 40.69218, 40.690635, 40.683665999999995, 40.677316, 40.670846999999995, 40.665414, 40.660396999999996, 40.655144, 40.648939, 40.645069, 40.641362, 40.634966999999996, 40.629742, 40.622687, 40.616622, 40.684459999999994, 40.67705, 40.661614, 40.655291999999996, 40.650527000000004, 40.644031, 40.640927000000005, 40.635082000000004, 40.62927, 40.625039, 40.617618, 40.608670000000004, 40.5
# ...
